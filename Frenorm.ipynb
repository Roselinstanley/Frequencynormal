# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv("prekidney.csv")
quan=[]
qual=[]
dataset
# Out:
#       id   age    bp    sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.02  1.0  0.0  normal    normal  notpresent
# 1      1   9.0  55.0  1.02  4.0  0.0  normal    normal  notpresent
# 2      2  62.0  80.0  1.01  2.0  0.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.00  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.01  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...   ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.02  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.02  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.02  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.02  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.02  0.0  0.0  normal    normal  notpresent
#
#              ba  ...   pcv      wc   rc  htn   dm  cad  appet   pe  ane  \
# 0    notpresent  ...  44.0  7800.0  5.2  yes  yes   no   good   no   no
# 1    notpresent  ...  38.0  6000.0  4.8   no   no   no   good   no   no
# 2    notpresent  ...  31.0  7500.0  4.8   no  yes   no   poor   no  yes
# 3    notpresent  ...  32.0  6700.0  3.9  yes   no   no   poor  yes  yes
# 4    notpresent  ...  35.0  7300.0  4.6   no   no   no   good   no   no
# ..          ...  ...   ...     ...  ...  ...  ...  ...    ...  ...  ...
# 395  notpresent  ...  47.0  6700.0  4.9   no   no   no   good   no   no
# 396  notpresent  ...  54.0  7800.0  6.0   no   no   no   good   no   no
# 397  notpresent  ...  49.0  6600.0  5.4   no   no   no   good   no   no
# 398  notpresent  ...  51.0  7200.0  5.9   no   no   no   good   no   no
# 399  notpresent  ...  53.0  6800.0  6.0   no   no   no   good   no   no
#
#     classification
# 0              ckd
# 1              ckd
# 2              ckd
# 3              ckd
# 4              ckd
# ..             ...
# 395         notckd
# 396         notckd
# 397         notckd
# 398         notckd
# 399         notckd
#
# [400 rows x 26 columns]

# %%
df=pd.DataFrame(dataset)
dfid=pd.DataFrame(dataset['id'])

# %%
df=df.drop(["id"],axis=1)
dataset=df

# %%
#Splitting numerical and categorical data
from Univariatekidney import univar
u=univar(dataset)
qual,quan=u.quanqual()

# %%
# In the dataset PCV,RC,WC are  umeric values but its typr is object so it is been converted to numeric value
dataset['pcv']=pd.to_numeric(dataset['pcv'],errors='coerce')
dataset['wc']=pd.to_numeric(dataset['wc'],errors='coerce')
dataset['rc']=pd.to_numeric(dataset['rc'],errors='coerce')

# %%
dataset.isnull().sum()
# Out:
# age               0
# bp                0
# sg                0
# al                0
# su                0
# rbc               0
# pc                0
# pcc               0
# ba                0
# bgr               0
# bu                0
# sc                0
# sod               0
# pot               0
# hemo              0
# pcv               0
# wc                0
# rc                0
# htn               0
# dm                0
# cad               0
# appet             0
# pe                0
# ane               0
# classification    0
# dtype: int64

# %%
from Freqnorm import Freqnorm
f=Freqnorm(dataset)
for cname in quan:   
    freq,skewness,kurtosis,variance,std=f.frequency(cname)     
    print("\n\n",cname,"\n\n")
    print(freq)
    print("\n\nskewness value of",cname,"=",skewness)
    print("\n\nKurtosis value of",cname,"=",kurtosis)
    print("\n\nVariance value of",cname,"=",variance)
    print("\n\nSD value of",cname,"=",std)
# Out:
#  age
#
#
#     Unique Values  Frequency  Relative Frequency       CRF
# 0            55.0         21            0.300000  0.300000
# 1            60.0         19            0.271429  0.571429
# 2            65.0         17            0.242857  0.814286
# 3            48.0         12            0.171429  0.985714
# 4            50.0         12            0.171429  1.157143
# ..            ...        ...                 ...       ...
# 65           14.0          1            0.014286  5.657143
# 66           81.0          1            0.014286  5.671429
# 67           11.0          1            0.014286  5.685714
# 68           26.0          1            0.014286  5.700000
# 69           79.0          1            0.014286  5.714286
#
# [70 rows x 4 columns]
#
#
# skewness value of age = -0.6222064032922697
#
#
# Kurtosis value of age = -0.07621934738870939
#
#
# Variance value of age = 280.76515664160394
#
#
# SD value of age = 16.756048359968528
#
#
#  bp
#
#
#    Unique Values  Frequency  Relative Frequency        CRF
# 0           80.0        128           21.333333  21.333333
# 1           70.0        112           18.666667  40.000000
# 2           60.0         71           11.833333  51.833333
# 3           90.0         53            8.833333  60.666667
# 4           95.0         31            5.166667  65.833333
# 5           55.0          5            0.833333  66.666667
#
#
# skewness value of bp = 0.05751869191050337
#
#
# Kurtosis value of bp = -0.9345383218311336
#
#
# Variance value of bp = 120.37030075188031
#
#
# SD value of bp = 10.971339970663578
#
#
#  sg
#
#
#    Unique Values  Frequency  Relative Frequency         CRF
# 0           1.02        234           78.000000   78.000000
# 1           1.01        159           53.000000  131.000000
# 2           1.00          7            2.333333  133.333333
#
#
# skewness value of sg = -0.6266851682556343
#
#
# Kurtosis value of sg = -0.8680634882771074
#
#
# Variance value of sg = 2.8114661654135634e-05
#
#
# SD value of sg = 0.0053023260607148286
#
#
#  al
#
#
#    Unique Values  Frequency  Relative Frequency        CRF
# 0            0.0        245           40.833333  40.833333
# 1            1.0         44            7.333333  48.166667
# 2            2.0         43            7.166667  55.333333
# 3            3.0         43            7.166667  62.500000
# 4            4.0         24            4.000000  66.500000
# 5            5.0          1            0.166667  66.666667
#
#
# skewness value of al = 1.1800875289466923
#
#
# Kurtosis value of al = 0.02278426003080325
#
#
# Variance value of al = 1.7243107769423354
#
#
# SD value of al = 1.3131301447085644
#
#
#  su
#
#
#    Unique Values  Frequency  Relative Frequency    CRF
# 0            0.0        400               400.0  400.0
#
#
# skewness value of su = 0.0
#
#
# Kurtosis value of su = 0.0
#
#
# Variance value of su = 0.0
#
#
# SD value of su = 0.0
#
#
#  bgr
#
#
#     Unique Values  Frequency  Relative Frequency   CRF
# 0           223.5         52                0.52  0.52
# 1           121.0         48                0.48  1.00
# 2            99.0         10                0.10  1.10
# 3           100.0          9                0.09  1.19
# 4            93.0          9                0.09  1.28
# ..            ...        ...                 ...   ...
# 95          160.0          1                0.01  3.96
# 96          148.0          1                0.01  3.97
# 97           84.0          1                0.01  3.98
# 98          143.0          1                0.01  3.99
# 99          162.0          1                0.01  4.00
#
# [100 rows x 4 columns]
#
#
# skewness value of bgr = 0.9083171154588494
#
#
# Kurtosis value of bgr = -0.31674175980645414
#
#
# Variance value of bgr = 2124.5117778822073
#
#
# SD value of bgr = 46.0924264698899
#
#
#  bu
#
#
#     Unique Values  Frequency  Relative Frequency       CRF
# 0         113.875         41            0.493976  0.493976
# 1          42.000         24            0.289157  0.783133
# 2          46.000         15            0.180723  0.963855
# 3          25.000         13            0.156627  1.120482
# 4          19.000         11            0.132530  1.253012
# ..            ...        ...                 ...       ...
# 78         75.000          1            0.012048  4.771084
# 79         21.000          1            0.012048  4.783133
# 80         65.000          1            0.012048  4.795181
# 81        103.000          1            0.012048  4.807229
# 82         76.000          1            0.012048  4.819277
#
# [83 rows x 4 columns]
#
#
# skewness value of bu = 0.9998465836146874
#
#
# Kurtosis value of bu = -0.1440304660239904
#
#
# Variance value of bu = 917.1178358043568
#
#
# SD value of bu = 30.283953437494862
#
#
#  sc
#
#
#     Unique Values  Frequency  Relative Frequency       CRF
# 0          5.4625         53            1.261905  1.261905
# 1          1.2000         40            0.952381  2.214286
# 2          1.3000         25            0.595238  2.809524
# 3          1.1000         24            0.571429  3.380952
# 4          0.5000         23            0.547619  3.928571
# 5          1.0000         23            0.547619  4.476190
# 6          0.9000         22            0.523810  5.000000
# 7          0.7000         22            0.523810  5.523810
# 8          0.6000         18            0.428571  5.952381
# 9          0.8000         17            0.404762  6.357143
# 10         2.2000         10            0.238095  6.595238
# 11         1.5000          9            0.214286  6.809524
# 12         1.7000          9            0.214286  7.023810
# 13         1.6000          8            0.190476  7.214286
# 14         2.5000          7            0.166667  7.380952
# 15         2.8000          7            0.166667  7.547619
# 16         1.4000          7            0.166667  7.714286
# 17         1.8000          7            0.166667  7.880952
# 18         1.9000          6            0.142857  8.023810
# 19         3.2000          5            0.119048  8.142857
# 20         3.3000          5            0.119048  8.261905
# 21         2.0000          5            0.119048  8.380952
# 22         2.1000          5            0.119048  8.500000
# 23         2.7000          5            0.119048  8.619048
# 24         3.9000          4            0.095238  8.714286
# 25         3.4000          3            0.071429  8.785714
# 26         2.3000          3            0.071429  8.857143
# 27         5.3000          3            0.071429  8.928571
# 28         4.0000          3            0.071429  9.000000
# 29         2.4000          3            0.071429  9.071429
# 30         2.9000          3            0.071429  9.142857
# 31         4.6000          2            0.047619  9.190476
# 32         4.1000          2            0.047619  9.238095
# 33         4.4000          2            0.047619  9.285714
# 34         3.0000          2            0.047619  9.333333
# 35         5.2000          2            0.047619  9.380952
# 36         3.2500          1            0.023810  9.404762
# 37         3.6000          1            0.023810  9.428571
# 38         3.8000          1            0.023810  9.452381
# 39         2.6000          1            0.023810  9.476190
# 40         4.3000          1            0.023810  9.500000
# 41         0.4000          1            0.023810  9.523810
#
#
# skewness value of sc = 1.1794348415181033
#
#
# Kurtosis value of sc = -0.02012191690314591
#
#
# Variance value of sc = 2.659235564497183
#
#
# SD value of sc = 1.630716273450775
#
#
#  sod
#
#
#     Unique Values  Frequency  Relative Frequency        CRF
# 0           138.0        107            4.652174   4.652174
# 1           135.0         40            1.739130   6.391304
# 2           140.0         25            1.086957   7.478261
# 3           141.0         22            0.956522   8.434783
# 4           139.0         21            0.913043   9.347826
# 5           142.0         20            0.869565  10.217391
# 6           137.0         19            0.826087  11.043478
# 7           150.0         18            0.782609  11.826087
# 8           126.0         18            0.782609  12.608696
# 9           136.0         17            0.739130  13.347826
# 10          147.0         13            0.565217  13.913043
# 11          145.0         11            0.478261  14.391304
# 12          146.0         10            0.434783  14.826087
# 13          132.0         10            0.434783  15.260870
# 14          131.0          9            0.391304  15.652174
# 15          144.0          9            0.391304  16.043478
# 16          133.0          8            0.347826  16.391304
# 17          130.0          7            0.304348  16.695652
# 18          134.0          6            0.260870  16.956522
# 19          143.0          4            0.173913  17.130435
# 20          127.0          3            0.130435  17.260870
# 21          128.0          2            0.086957  17.347826
# 22          129.0          1            0.043478  17.391304
#
#
# skewness value of sod = -0.04306421368354811
#
#
# Kurtosis value of sod = 0.47587603051815064
#
#
# Variance value of sod = 27.809718045112707
#
#
# SD value of sod = 5.273492016217784
#
#
#  pot
#
#
#     Unique Values  Frequency  Relative Frequency       CRF
# 0             4.4        102             3.18750   3.18750
# 1             3.5         30             0.93750   4.12500
# 2             5.0         30             0.93750   5.06250
# 3             4.9         27             0.84375   5.90625
# 4             4.7         17             0.53125   6.43750
# 5             4.8         16             0.50000   6.93750
# 6             4.1         14             0.43750   7.37500
# 7             4.0         14             0.43750   7.81250
# 8             3.9         14             0.43750   8.25000
# 9             3.8         14             0.43750   8.68750
# 10            4.2         14             0.43750   9.12500
# 11            4.5         13             0.40625   9.53125
# 12            4.3         12             0.37500   9.90625
# 13            3.7         12             0.37500  10.28125
# 14            6.0         10             0.31250  10.59375
# 15            3.6          8             0.25000  10.84375
# 16            4.6          7             0.21875  11.06250
# 17            3.4          5             0.15625  11.21875
# 18            5.2          5             0.15625  11.37500
# 19            2.8          4             0.12500  11.50000
# 20            5.3          4             0.12500  11.62500
# 21            5.7          4             0.12500  11.75000
# 22            5.4          3             0.09375  11.84375
# 23            3.2          3             0.09375  11.93750
# 24            2.9          3             0.09375  12.03125
# 25            5.5          3             0.09375  12.12500
# 26            3.3          3             0.09375  12.21875
# 27            5.8          2             0.06250  12.28125
# 28            5.9          2             0.06250  12.34375
# 29            5.6          2             0.06250  12.40625
# 30            3.0          2             0.06250  12.46875
# 31            5.1          1             0.03125  12.50000
#
#
# skewness value of pot = 0.15294785336946448
#
#
# Kurtosis value of pot = 0.28669603359668017
#
#
# Variance value of pot = 0.40358640350877273
#
#
# SD value of pot = 0.6352845059567979
#
#
#  hemo
#
#
#      Unique Values  Frequency  Relative Frequency       CRF
# 0            12.65         52            0.452174  0.452174
# 1            15.00         16            0.139130  0.591304
# 2            10.90          8            0.069565  0.660870
# 3            13.60          7            0.060870  0.721739
# 4            13.00          7            0.060870  0.782609
# ..             ...        ...                 ...       ...
# 110           6.60          1            0.008696  3.443478
# 111           6.30          1            0.008696  3.452174
# 112           9.20          1            0.008696  3.460870
# 113          12.90          1            0.008696  3.469565
# 114          17.60          1            0.008696  3.478261
#
# [115 rows x 4 columns]
#
#
# skewness value of hemo = -0.3242479509904767
#
#
# Kurtosis value of hemo = -0.27718037309547094
#
#
# Variance value of hemo = 7.272141854636598
#
#
# SD value of hemo = 2.696690908249701
#
#
#  pcv
#
#
#     Unique Values  Frequency  Relative Frequency        CRF
# 0            40.0         87            2.416667   2.416667
# 1            41.0         21            0.583333   3.000000
# 2            52.0         21            0.583333   3.583333
# 3            44.0         19            0.527778   4.111111
# 4            48.0         19            0.527778   4.638889
# 5            43.0         15            0.416667   5.055556
# 6            42.0         13            0.361111   5.416667
# 7            45.0         13            0.361111   5.777778
# 8            33.0         12            0.333333   6.111111
# 9            28.0         12            0.333333   6.444444
# 10           50.0         12            0.333333   6.777778
# 11           32.0         12            0.333333   7.111111
# 12           36.0         12            0.333333   7.444444
# 13           37.0         11            0.305556   7.750000
# 14           34.0         11            0.305556   8.055556
# 15           29.0          9            0.250000   8.305556
# 16           35.0          9            0.250000   8.555556
# 17           30.0          9            0.250000   8.805556
# 18           46.0          9            0.250000   9.055556
# 19           19.0          8            0.222222   9.277778
# 20           31.0          8            0.222222   9.500000
# 21           39.0          7            0.194444   9.694444
# 22           24.0          7            0.194444   9.888889
# 23           26.0          6            0.166667  10.055556
# 24           38.0          5            0.138889  10.194444
# 25           53.0          4            0.111111  10.305556
# 26           47.0          4            0.111111  10.416667
# 27           49.0          4            0.111111  10.527778
# 28           51.0          4            0.111111  10.638889
# 29           54.0          4            0.111111  10.750000
# 30           25.0          3            0.083333  10.833333
# 31           27.0          3            0.083333  10.916667
# 32           22.0          3            0.083333  11.000000
# 33           23.0          2            0.055556  11.055556
# 34           20.0          1            0.027778  11.083333
# 35           21.0          1            0.027778  11.111111
#
#
# skewness value of pcv = -0.4080078279349062
#
#
# Kurtosis value of pcv = -0.197163020598488
#
#
# Variance value of pcv = 63.713258145363426
#
#
# SD value of pcv = 7.982058515531155
#
#
#  wc
#
#
#     Unique Values  Frequency  Relative Frequency       CRF
# 0          8000.0        109            1.415584  1.415584
# 1         13037.5         15            0.194805  1.610390
# 2          9800.0         11            0.142857  1.753247
# 3          6700.0         10            0.129870  1.883117
# 4          7200.0          9            0.116883  2.000000
# ..            ...        ...                 ...       ...
# 72        10900.0          1            0.012987  5.142857
# 73        12300.0          1            0.012987  5.155844
# 74        11200.0          1            0.012987  5.168831
# 75        12500.0          1            0.012987  5.181818
# 76         4900.0          1            0.012987  5.194805
#
# [77 rows x 4 columns]
#
#
# skewness value of wc = 0.3581879779944261
#
#
# Kurtosis value of wc = 0.23012321598369212
#
#
# Variance value of wc = 4123826.635925752
#
#
# SD value of wc = 2030.7207183474916
#
#
#  rc
#
#
#     Unique Values  Frequency  Relative Frequency    CRF
# 0             4.8        141                5.64   5.64
# 1             3.6         43                1.72   7.36
# 2             6.0         32                1.28   8.64
# 3             5.2         18                0.72   9.36
# 4             4.5         16                0.64  10.00
# 5             4.9         14                0.56  10.56
# 6             4.7         11                0.44  11.00
# 7             5.0         10                0.40  11.40
# 8             3.9         10                0.40  11.80
# 9             4.6          9                0.36  12.16
# 10            5.5          8                0.32  12.48
# 11            3.7          8                0.32  12.80
# 12            5.9          8                0.32  13.12
# 13            5.4          7                0.28  13.40
# 14            5.8          7                0.28  13.68
# 15            3.8          7                0.28  13.96
# 16            5.3          7                0.28  14.24
# 17            4.2          6                0.24  14.48
# 18            4.3          6                0.24  14.72
# 19            5.6          6                0.24  14.96
# 20            4.0          6                0.24  15.20
# 21            4.4          5                0.20  15.40
# 22            4.1          5                0.20  15.60
# 23            5.1          5                0.20  15.80
# 24            5.7          5                0.20  16.00
#
#
# skewness value of rc = -0.03472183058748854
#
#
# Kurtosis value of rc = -0.41447947702538146
#
#
# Variance value of rc = 0.45539843358395987
#
#
# SD value of rc = 0.6748321521563416

# %%
f.cal_PDF(quan)
# Out:
# Enter the start range,endrange,no for PDF age
#  70
#  90
#  80
# C:\Users\Admin\Desktop\AI\Univariate assignment with kidney dataset\Freqnorm.py:26: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sb.distplot(self.dataset[cname],kde=True,kde_kws={'color':'pink'},color='Green')
# The area of age  between the range (70,90):(0.13137335231950106,13.137335231950106)0.99
# Enter the start range,endrange,no for PDF bp
#  70
#  90
#  60
# C:\Users\Admin\Desktop\AI\Univariate assignment with kidney dataset\Freqnorm.py:26: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sb.distplot(self.dataset[cname],kde=True,kde_kws={'color':'pink'},color='Green')
# The area of bp  between the range (70,90):(0.6117053017610878,61.170530176108784)0.19
# Enter the start range,endrange,no for PDF sg
#  1
#  1
#  1
# C:\Users\Admin\Desktop\AI\Univariate assignment with kidney dataset\Freqnorm.py:26: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sb.distplot(self.dataset[cname],kde=True,kde_kws={'color':'pink'},color='Green')
# The area of sg  between the range (1,1):(0,0)0.017499999999999998
# Enter the start range,endrange,no for PDF al
#  2
#  4
#  3
# C:\Users\Admin\Desktop\AI\Univariate assignment with kidney dataset\Freqnorm.py:26: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sb.distplot(self.dataset[cname],kde=True,kde_kws={'color':'pink'},color='Green')
# The area of al  between the range (2,4):(0.29848069739619565,29.848069739619564)0.9375
# Enter the start range,endrange,no for PDF su
#  0
#  0
#  0
# C:\Users\Admin\Desktop\AI\Univariate assignment with kidney dataset\Freqnorm.py:26: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sb.distplot(self.dataset[cname],kde=True,kde_kws={'color':'pink'},color='Green')
# C:\Anaconda3\Lib\site-packages\seaborn\distributions.py:2496: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# The area of su  between the range (0,0):(0,0)1.0
# Enter the start range,endrange,no for PDF bgr
#  150
#  200
#  180
# C:\Users\Admin\Desktop\AI\Univariate assignment with kidney dataset\Freqnorm.py:26: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sb.distplot(self.dataset[cname],kde=True,kde_kws={'color':'pink'},color='Green')
# The area of bgr  between the range (150,200):(0.2907376702946616,29.073767029466158)0.8099999999999999
# Enter the start range,endrange,no for PDF bu
#  60
#  90
#  75
# C:\Users\Admin\Desktop\AI\Univariate assignment with kidney dataset\Freqnorm.py:26: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sb.distplot(self.dataset[cname],kde=True,kde_kws={'color':'pink'},color='Green')
# The area of bu  between the range (60,90):(0.28273374190234746,28.273374190234748)0.7999999999999999
# Enter the start range,endrange,no for PDF sc
#  2
#  5
#  3
# C:\Users\Admin\Desktop\AI\Univariate assignment with kidney dataset\Freqnorm.py:26: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sb.distplot(self.dataset[cname],kde=True,kde_kws={'color':'pink'},color='Green')
# The area of sc  between the range (2,5):(0.5739994991127901,57.399949911279016)0.7799999999999999
# Enter the start range,endrange,no for PDF sod
#  120
#  150
#  130
# C:\Users\Admin\Desktop\AI\Univariate assignment with kidney dataset\Freqnorm.py:26: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sb.distplot(self.dataset[cname],kde=True,kde_kws={'color':'pink'},color='Green')
# The area of sod  between the range (120,150):(0.9837415883684977,98.37415883684977)0.0775
# Enter the start range,endrange,no for PDF pot
#  2
#  5
#  3
# C:\Users\Admin\Desktop\AI\Univariate assignment with kidney dataset\Freqnorm.py:26: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sb.distplot(self.dataset[cname],kde=True,kde_kws={'color':'pink'},color='Green')
# The area of pot  between the range (2,5):(0.5830747376614546,58.307473766145456)0.0225
# Enter the start range,endrange,no for PDF hemo
#  12
#  16
#  14
# C:\Users\Admin\Desktop\AI\Univariate assignment with kidney dataset\Freqnorm.py:26: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sb.distplot(self.dataset[cname],kde=True,kde_kws={'color':'pink'},color='Green')
# The area of hemo  between the range (12,16):(0.5166678369229041,51.66678369229041)0.7
# Enter the start range,endrange,no for PDF pcv
#  25
#  53
#  40
# C:\Users\Admin\Desktop\AI\Univariate assignment with kidney dataset\Freqnorm.py:26: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sb.distplot(self.dataset[cname],kde=True,kde_kws={'color':'pink'},color='Green')
# The area of pcv  between the range (25,53):(0.9197733568462197,91.97733568462198)0.595
# Enter the start range,endrange,no for PDF wc
#  6000
#  9000
#  7500
# C:\Users\Admin\Desktop\AI\Univariate assignment with kidney dataset\Freqnorm.py:26: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sb.distplot(self.dataset[cname],kde=True,kde_kws={'color':'pink'},color='Green')
# The area of wc  between the range (6000,9000):(0.5160283326774576,51.602833267745766)0.3225
# Enter the start range,endrange,no for PDF rc
#  3
#  5
#  4
# C:\Users\Admin\Desktop\AI\Univariate assignment with kidney dataset\Freqnorm.py:26: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sb.distplot(self.dataset[cname],kde=True,kde_kws={'color':'pink'},color='Green')
# The area of rc  between the range (3,5):(0.3274299834333598,32.74299834333598)0.185

# %%
f.std_normal(quan)
# Out:
# The Z_SCORE plot of age
# The Z_SCORE plot of bp
# The Z_SCORE plot of sg
# The Z_SCORE plot of al
# The Z_SCORE plot of su
# C:\Users\Admin\Desktop\AI\Univariate assignment with kidney dataset\Freqnorm.py:46: RuntimeWarning: invalid value encountered in scalar divide
#   z_score=[((j-mean)/std) for j in values]
# The Z_SCORE plot of bgr
# The Z_SCORE plot of bu
# The Z_SCORE plot of sc
# The Z_SCORE plot of sod
# The Z_SCORE plot of pot
# The Z_SCORE plot of hemo
# The Z_SCORE plot of pcv
# The Z_SCORE plot of wc
# The Z_SCORE plot of rc
#       Z_score
# 0    0.637566
# 1    0.044826
# 2    0.044826
# 3   -1.288839
# 4   -0.251544
# ..        ...
# 395  0.193011
# 396  1.823046
# 397  0.933936
# 398  1.674861
# 399  1.823046
#
# [400 rows x 1 columns]
